# %% [markdown]
# ### Get the model

# %%
from ProcessSimulator.src.processes.simple_window_process import WindowSimulator
graph = WindowSimulator()

# %%
# if you have enabled widgetsnbextension for jupyter:
#model.print_graph_interactive()
#else
graph.print_graph()

# %%
#{assets/Evaluation/window_process/process_graph.pgf}
graph.save_graph_tikz()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/dot2tex/dot2tex.py in parse_drawstring(drawstring)
#     331             if c in ('e', 'E'):
# --> 332                 didx, cmd = doeE(c, s[idx + 1:])
#     333                 cmdlist.append(cmd)
#
# /usr/local/lib/python3.9/dist-packages/dot2tex/dot2tex.py in doeE(c, s)
#     261             return None
# --> 262         points = [float(t) for t in tokens]
#     263         didx = sum(len(t) for t in tokens) + len(points) + 1
#
# /usr/local/lib/python3.9/dist-packages/dot2tex/dot2tex.py in <listcomp>(.0)
#     261             return None
# --> 262         points = [float(t) for t in tokens]
#     263         didx = sum(len(t) for t in tokens) + len(points) + 1
#
# ValueError: could not convert string to float: '/erik/PycharmProjects/Masterthesis/code/notebooks/Evaluation/sensor_temperature_0.svg'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_81767/3020345573.py in <module>
#       1 #{assets/Evaluation/window_process/process_graph.pgf}
# ----> 2 graph.save_graph_tikz()
#       3
#
# ~/PycharmProjects/Masterthesis/code/ProcessSimulator/src/simulator/process_model.py in save_graph_tikz(self, path, probabilities, conditional_probability)
#     592     def save_graph_tikz(self, path='output', probabilities=False, conditional_probability=False):
#     593         graph = self.get_dot_graph(probabilities=probabilities, conditional_probability=conditional_probability)
# --> 594         texcode = dot2tex.dot2tex(graph.to_string(), format='pgf', crop=True, figonly=True)
#     595         with open(path + '.pgf', 'w') as f:
#     596             f.write(texcode)
#
# /usr/local/lib/python3.9/dist-packages/dot2tex/__init__.py in dot2tex(dotsource, **kwargs)
#      60
#      61     """
# ---> 62     return d2t.convert_graph(dotsource, **kwargs)
#      63
#      64
#
# /usr/local/lib/python3.9/dist-packages/dot2tex/dot2tex.py in convert_graph(dotsource, **kwargs)
#    3123
#    3124     options.__dict__.update(kwargs)
# -> 3125     tex = main(True, dotsource, options)
#    3126     return tex
#    3127
#
# /usr/local/lib/python3.9/dist-packages/dot2tex/dot2tex.py in main(run_as_module, dotdata, options)
#    3073         sys.exit(1)
#    3074     try:
# -> 3075         s = conv.convert(dotdata)
#    3076         log.debug('Output:\n%s', s)
#    3077         if options.autosize:
#
# /usr/local/lib/python3.9/dist-packages/dot2tex/dot2tex.py in convert(self, dotdata)
#     827             if not self.options.get('switchdraworder'):
#     828                 self.do_edges()  # tmp
# --> 829                 self.do_nodes()
#     830             else:
#     831                 self.do_nodes()
#
# /usr/local/lib/python3.9/dist-packages/dot2tex/dot2tex.py in do_nodes(self)
#     647             s += self.output_node_comment(node)
#     648             s += self.start_node(node)
# --> 649             s += self.do_drawstring(drawstring, node)
#     650             s += self.end_node(node)
#     651         self.body += s
#
# /usr/local/lib/python3.9/dist-packages/dot2tex/dot2tex.py in do_drawstring(self, drawstring, drawobj, texlbl_name, use_drawstring_pos)
#     534         Just a wrapper around do_draw_op.
#     535         """
# --> 536         drawoperations, stat = parse_drawstring(drawstring)
#     537         return self.do_draw_op(drawoperations, drawobj, stat, texlbl_name, use_drawstring_pos)
#     538
#
# /usr/local/lib/python3.9/dist-packages/dot2tex/dot2tex.py in parse_drawstring(drawstring)
#     345                 cmdlist.append(cmd)
#     346         except Exception as err:
# --> 347             log.debug("Failed to parse drawstring %s\n%s", s, err.message)
#     348
#     349         idx += didx
#
# AttributeError: 'ValueError' object has no attribute 'message'

# %%
#graph.save_graph_png(path='probabilities_v3.png',probabilities=True)
