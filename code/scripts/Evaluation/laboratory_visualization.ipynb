# %% [markdown]
# ### Get the model

# %%
from ProcessSimulator.src.processes.laboratory_process_sensor import LaboratorySimulator
graph = LaboratorySimulator()

# %%
# if you have enabled widgetsnbextension for jupyter:
#model.print_graph_interactive()
#else
graph.print_graph()#probabilities=True, conditional_probability=True)

# %%
from utils import get_assets_path
#{assets/Evaluation/window_process/process_graph.pgf}
#graph.save_graph_tikz(path=get_assets_path() / 'datasets' / 'laboratory' / 'probabilities')

# %%
#graph.save_graph_png(path=get_assets_path() / 'datasets' / 'laboratory' / 'process_graph' ,
#                     probabilities=True, conditional_probability=True)
