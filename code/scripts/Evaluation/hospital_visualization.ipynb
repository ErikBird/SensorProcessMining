# %% [markdown]
# ### Get the model

# %%
from ProcessSimulator.src.processes import HospitalSimulator
graph = HospitalSimulator()

# %%
# if you have enabled widgetsnbextension for jupyter:
#model.print_graph_interactive()
#else
graph.print_graph()#probabilities=True, conditional_probability=True)

# %%
from utils import get_assets_path

graph.save_graph_png(path=get_assets_path() / 'datasets' / 'hospital' / 'process_graph' ,
                     probabilities=True, conditional_probability=True)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]2021-11-01 10:09:06.709730: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-01 10:09:06.714535: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-01 10:09:06.714968: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-01 10:09:06.715814: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-01 10:09:06.716477: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-01 10:09:06.716876: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-01 10:09:06.717180: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-01 10:09:07.039225: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-01 10:09:07.039592: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-01 10:09:07.039899: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-01 10:09:07.040184: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4540 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:26:00.0, compute capability: 7.5
# 100%|██████████| 100000/100000 [00:29<00:00, 3415.83it/s]
# {('start', 'reception'): 0.1063, ('reception', 'create'): 0.05314, ('create', 'nurse'): 0.05314, ('nurse', 'wait'): 0.09572, ('wait', 'triage'): 0.09572, ('triage', 'diagnosis'): 0.1063, ('diagnosis', 'prescribe'): 0.03733, ('prescribe', 'clinic'): 0.01841, ('clinic', 'end'): 0.01841, ('end', 'start'): 0.1063, ('reception', 'retrieve'): 0.05316, ('retrieve', 'nurse'): 0.05316, ('diagnosis', 'discharge'): 0.06897, ('discharge', 'end'): 0.08552, ('nurse', 'triage'): 0.01058, ('prescribe', 'hypertension'): 0.01655, ('hypertension', 'discharge'): 0.01655, ('prescribe', 'emergency'): 0.00237, ('emergency', 'end'): 0.00237}

# %%
#graph.save_graph_png(path='probabilities_v3.png',probabilities=True)
